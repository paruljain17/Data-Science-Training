# %%
import os
train_path = 'dataset/train/images'
test_path = "dataset/test/images"
print(os.path.exists(train_path))
print(os.path.exists(test_path))
# Out:
# True
# True

# %%
os.getcwd()
# Out:
# 'c:\\Users\\parul\\OneDrive\\Desktop\\Training\\DL\\CNN\\ASL'
