# %%
## TF-IDF ----> term frequency-Inverse document frequency

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer()

# %%
doc = ["good boy","good girl","boy girl good"]
print(vectorizer.fit_transform(doc).toarray())
print(vectorizer.vocabulary_)
print(vectorizer.idf_)
print(vectorizer.get_feature_names_out())
# Out:
# [[0.78980693 0.         0.61335554]
#  [0.         0.78980693 0.61335554]
#  [0.61980538 0.61980538 0.48133417]]
# {'good': 2, 'boy': 0, 'girl': 1}
# [1.28768207 1.28768207 1.        ]
# ['boy' 'girl' 'good']

# %%
## word embedding
#1-- count or frequency-- one hot , bow, ngram , tfidf
#2-- deep learning pre trained models -- word2vect(Cbow and skipgram), Glove, Fasttext

# %%
## word2vec -- google -- 2013 -- news data --300Billion
## fasttext -- facebook --2017 -- news data --1B

# %%
##cosine similarity
